# %%
import random
from math import exp, log

# %%
# Data prepration

X = [(0,0), (1,0), (0,1), (1,1)]
Y = [0,0,0,1]

# %%
# Model

class logistic_regression_model():
    def __init__(self):
        self.w = [random.random(), random.random()]
        self.b = random.random()
        
    def sigmoid(self, z):
        return 1/(1 + exp(-z))
    
    def predict(self, x):
        z = self.w[0] * x[0] + self.w[1] * x[1] + self.b
        a = self.sigmoid(z)
        return a

# %%
model = logistic_regression_model()

# %%
# Training

def train(X, Y, model, Ir = 0.1):
    dw0 = 0.0
    dw1 = 0.0
    db = 0.0
    m = len(X)
    cost = 0.0
    for x, y in zip(X, Y):
        a = model.predict(x)
        if y == 1:
            cost -= log(a)
        else:
            cost -= log(1-a)
            
        dw0 += (a-y)*x[0]
        dw1 += (a-y)*x[1]
        db += (a-y)
            
    cost /= m
    model.w[0] -= Ir * dw0/m
    model.w[1] -= Ir * dw1/m
    model.b -= Ir*db/m
        
    return cost

# %%
for epoch in range(10000):
    cost = train(X, Y, model, 0.1)
    if epoch % 100 == 0:
        print(epoch, cost)
# Out:
# 0 0.01637228565654212
# 100 0.016219420236492168
# 200 0.016069354065267286
# 300 0.01592201145359422
# 400 0.01577731940366334
# 500 0.015635207490987048
# 600 0.015495607752407926
# 700 0.015358454579888619
# 800 0.015223684619738486
# 900 0.015091236676955767
# 1000 0.014961051624385532
# 1100 0.014833072316414186
# 1200 0.014707243506938035
# 1300 0.01458351177136228
# 1400 0.01446182543240206
# 1500 0.01434213448947012
# 1600 0.014224390551453324
# 1700 0.014108546772687287
# 1800 0.013994557791956155
# 1900 0.013882379674350987
# 2000 0.013771969855831404
# 2100 0.013663287090347587
# 2200 0.013556291399383373
# 2300 0.013450944023794625
# 2400 0.01334720737782013
# 2500 0.01324504500515438
# 2600 0.013144421536972407
# 2700 0.013045302651809317
# 2800 0.012947655037197452
# 2900 0.012851446352973764
# 3000 0.01275664519617279
# 3100 0.012663221067425819
# 3200 0.012571144338791813
# 3300 0.012480386222949825
# 3400 0.012390918743685385
# 3500 0.012302714707609436
# 3600 0.012215747677048569
# 3700 0.012129991944052176
# 3800 0.012045422505462297
# 3900 0.0119620150389956
# 4000 0.011879745880291488
# 4100 0.011798592000879243
# 4200 0.01171853098702328
# 4300 0.011639541019405232
# 4400 0.011561600853604465
# 4500 0.011484689801341142
# 4600 0.011408787712447464
# 4700 0.011333874957533699
# 4800 0.011259932411318542
# 4900 0.01118694143659451
# 5000 0.011114883868799906
# 5100 0.011043742001171065
# 5200 0.01097349857044952
# 5300 0.010904136743120128
# 5400 0.010835640102157654
# 5500 0.010767992634259173
# 5600 0.010701178717543126
# 5700 0.010635183109693198
# 5800 0.010569990936530875
# 5900 0.010505587680996749
# 6000 0.01044195917252461
# 6100 0.010379091576791902
# 6200 0.01031697138583082
# 6300 0.010255585408486326
# 6400 0.010194920761205461
# 6500 0.010134964859146146
# 6600 0.010075705407591212
# 6700 0.0100171303936576
# 6800 0.009959228078285885
# 6900 0.009901986988502417
# 7000 0.009845395909941199
# 7100 0.009789443879616114
# 7200 0.009734120178933693
# 7300 0.009679414326937093
# 7400 0.009625316073773225
# 7500 0.00957181539437242
# 7600 0.009518902482335424
# 7700 0.009466567744017634
# 7800 0.009414801792803889
# 7900 0.009363595443567338
# 8000 0.009312939707304367
# 8100 0.009262825785940414
# 8200 0.009213245067298871
# 8300 0.009164189120228476
# 8400 0.009115649689883036
# 8500 0.009067618693147185
# 8600 0.0090200882142039
# 8700 0.008973050500238527
# 8800 0.008926497957273977
# 8900 0.00888042314613272
# 9000 0.008834818778521403
# 9100 0.00878967771323309
# 9200 0.008744992952463844
# 9300 0.008700757638238887
# 9400 0.008656965048945097
# 9500 0.008613608595966205
# 9600 0.008570681820416162
# 9700 0.008528178389969438
# 9800 0.008486092095782343
# 9900 0.008444416849504295

# %%
# Testing

model.predict((0, 0))
# Out:
# 1.37476599928571e-06

# %%
model.predict((0, 1))
# Out:
# 0.009828296650356335

# %%
model.predict((1, 0))
# Out:
# 0.009828298094120743

# %%
model.predict((1, 1))
# Out:
# 0.9862381874151579
